# %% [markdown]
# # Assignment 4: Benchmarking Neural Nets with the XOR Problem

# %% [markdown]
# ### CS 4774 Machine Learning - Department of Computer Science - University of Virginia
# In this assignment, you will implement your own neural networks to classify non-linear data from the XOR dataset. For references, you may refer to my [lecture 13](https://docs.google.com/presentation/d/1otQfmMomWctLZKI3hHKAA4lLkbXFtagLaQov8gNh4LI/edit?usp=sharing) and [Colab Notebook 10](https://colab.research.google.com/drive/1x5biI3dP5YvvDEI0wapJcSgQNnATDzNe) if you need additional sample codes to help with your assignment. For deliverables, you must write code in Python/Tensorflow and submit **this** Jupyter Notebook file (.ipynb) to earn a total of 100 pts. Note that you must save your Notebook filename under this format: **yourUvaUserId_assignment_4_ann.ipynb**.

# %%
# You might want to use the following packages
import sklearn
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

import numpy as np
np.random.seed(42)

import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## 1. THE DATASET AND VISUALIZATION
#
# We will use the non-linear toy data called the XOR dataset. You may use the code snippet below to generate the train/validate/test set. Feel free to change the number of samples, and noise level. To keep the ratio between the sets consistent, please do not change the test_size and random_state parameters.

# %%
def make_xor(n_points):
    centers = np.array([[0,0],[0,1],[1,0],[1,1]])
    labels = np.array([0,1,1,0])
    data = np.array([]).reshape(-1,3)
    for center, label in zip(centers,labels):
        points = np.random.normal(loc=center,scale=0.2,size=(n_points//4,2))
        points_labels = np.hstack((points,label*np.ones(n_points//4).reshape((-1, 1))))
        data = np.vstack((data,points_labels))
    return (data[:,[0,1]],data[:,2])


X, y = make_xor(1000)
y=y.astype(np.int64)
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2, random_state=49)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size= 0.1, random_state=49)
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral)
# Out:
# (720, 2)
# (200, 2)
# (80, 2)

# %% [markdown]
# ---
# ## 2. TRAIN A SIMPLE ANN FOR CLASSIFICATION TASK
#
# Use the standard libarary of Neural Net on the training data, and then test the classifier on the test data. You will create a simple ANN with 3 layers: an Input Layer, a Hidden Layer and an Output Layer. For each layer, you can specify the number of nodes appropriate for the XOR problem. Also, feel free to tune the network as you see fit. You have to report the accuracy of the network on the validation set.

# %%
import tensorflow as tf
from tensorflow import keras

my_model = keras.Sequential()
# Your code here!
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[2, ]))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(2, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy" ,
              optimizer="sgd",
              metrics=["accuracy"])

xor_library = model.fit(X_train, y_train, batch_size=64, epochs=20,
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 45ms/step - loss: 0.6888 - accuracy: 0.6014 - val_loss: 0.6871 - val_accuracy: 0.6250
# Epoch 2/20
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6838 - accuracy: 0.5931 - val_loss: 0.6808 - val_accuracy: 0.6250
# Epoch 3/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6791 - accuracy: 0.5972 - val_loss: 0.6742 - val_accuracy: 0.6250
# Epoch 4/20
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6744 - accuracy: 0.5889 - val_loss: 0.6694 - val_accuracy: 0.6250
# Epoch 5/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6700 - accuracy: 0.5819 - val_loss: 0.6648 - val_accuracy: 0.6250
# Epoch 6/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6657 - accuracy: 0.6056 - val_loss: 0.6587 - val_accuracy: 0.6125
# Epoch 7/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6613 - accuracy: 0.5847 - val_loss: 0.6545 - val_accuracy: 0.6125
# Epoch 8/20
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6574 - accuracy: 0.5903 - val_loss: 0.6491 - val_accuracy: 0.6125
# Epoch 9/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6535 - accuracy: 0.6167 - val_loss: 0.6458 - val_accuracy: 0.6125
# Epoch 10/20
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6498 - accuracy: 0.6514 - val_loss: 0.6406 - val_accuracy: 0.6875
# Epoch 11/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6461 - accuracy: 0.7153 - val_loss: 0.6365 - val_accuracy: 0.7750
# Epoch 12/20
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6425 - accuracy: 0.7806 - val_loss: 0.6322 - val_accuracy: 0.8375
# Epoch 13/20
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6390 - accuracy: 0.8125 - val_loss: 0.6286 - val_accuracy: 0.8625
# Epoch 14/20
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6355 - accuracy: 0.8431 - val_loss: 0.6247 - val_accuracy: 0.8750
# Epoch 15/20
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6320 - accuracy: 0.8667 - val_loss: 0.6210 - val_accuracy: 0.8875
# Epoch 16/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6284 - accuracy: 0.8806 - val_loss: 0.6175 - val_accuracy: 0.9000
# Epoch 17/20
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6250 - accuracy: 0.8931 - val_loss: 0.6148 - val_accuracy: 0.9000
# Epoch 18/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6216 - accuracy: 0.9000 - val_loss: 0.6117 - val_accuracy: 0.9125
# Epoch 19/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6182 - accuracy: 0.9167 - val_loss: 0.6077 - val_accuracy: 0.9125
# Epoch 20/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6147 - accuracy: 0.9194 - val_loss: 0.6045 - val_accuracy: 0.9125

# %%
xor_library.history['accuracy']
# Out:
# [0.6013888716697693,
#  0.5930555462837219,
#  0.5972222089767456,
#  0.5888888835906982,
#  0.581944465637207,
#  0.605555534362793,
#  0.5847222208976746,
#  0.5902777910232544,
#  0.6166666746139526,
#  0.6513888835906982,
#  0.7152777910232544,
#  0.7805555462837219,
#  0.8125,
#  0.8430555462837219,
#  0.8666666746139526,
#  0.8805555701255798,
#  0.8930555582046509,
#  0.8999999761581421,
#  0.9166666865348816,
#  0.9194444417953491]

# %% [markdown]
# - - -
# ## 3. IMPLEMENTING YOUR OWN SIMPLE NEURAL NETWORK
#
# Now that you see how the standard library ANN performs on the XOR dataset, you will attempt to implement your own version of the neural network. To help you, a template has been created including the backpropagation. Essensially, you will get the backward gradients for free. However, please note that the backprop implementation assume usage of tanh activation for the hidden layer and softmax for the output layer. There are some subtasks which you need to implement in order to get the network to work properly.

# %%
from sklearn.base import BaseEstimator
from sklearn.preprocessing import OneHotEncoder
from math import exp

class MyNeuralNet(BaseEstimator):
    """Your implementation of a simple neural network"""

    def __init__ (self, n0, n1, n2, alpha=0.01):
        """
        @param: n0: Number of nodes in the input layer
        @param: n1: Number of nodes in the hidden layer
        @param: n2: Number of nodes in the output layer
        @param: alpha: The Learning Rate
        """

        # SUBTASK 1: Initialize the parameters to random values.
        np.random.seed(42)
        self.W1 = np.random.rand(n1, n0)
        self.b1 = np.random.rand(n1, 1)
        self.W2 = np.random.rand(n2, n1)
        self.b2 = np.random.rand(n2, 1)

        # Configure the learning rate
        self.alpha = alpha
        # One-hot encoder for labels
        self.encoder = OneHotEncoder(sparse=False)

    def forward_pass(self, X):
        """
        Pass the signal forward through the layers.
        @param: X: feature
        @return: A1: saved value of the output of the hidden layer
        @return: A2: activated return value of the output layer.
        """
        # SUBTASK 2: Implement Forward propagation.
        # Note: that you must implement tanh activation for the hiden layer
        # and softmax for the output layer

        def softmax(m):
          numerator = np.exp(m)
          denominator = np.exp(m).sum(axis = 0)
          return numerator/denominator

        def tanh(m):
          numerator = np.exp(m) - np.exp(-m)
          denominator = np.exp(m) + np.exp(-m)
          return numerator/denominator


        Z1 = np.dot(self.W1, X) + self.b1
        A1 = tanh(Z1)
        Z2 = np.dot(self.W2, A1) + self.b2
        A2 = softmax(Z2)

        return A1, A2


    def loss(self, X, y):
        """
        Evaluate the total loss on the dataset
        @param: X: features
        @param: y: labels
        @return: L: the loss value
        """


        # SUBTASK 3: Calculate the loss using Cross-Entropy
        # You will need to return the average loss on the data
        # Hint: Use A2 to calculate the loss
        A1, A2 = self.forward_pass(X)
        # Another Hint: First, you may want to convert the lable y into a one-hot vector
        Y = self.one_hot(y)

        L = -np.sum(Y * np.log(A2)) / len(Y)

        return L

    def backward_pass(self, A1, A2, X, y):
        """
        @param: X: feature
        @param: y: label
        @param: A1: saved value of the output of the hidden layer
        @param: a2: activated return value of the output layer.

        @return: dW1: the loss gradient of W1
        @return: db1: the loss gradient of b1
        @return: dW2: the loss gradient of W2
        @return: db2: the loss gradient of b2
        """

        # You DO NOT CHANGE this function, ...
        # unless you are advanced and want to use different activation function for your forward pass
        # This is an elegant partial derivative of cross entropy with softmax
        # Ref document: https://deepnotes.io/softmax-crossentropy
        m   = y.shape[0]
        dZ2 = A2 - self.one_hot(y)
        dW2 = np.dot(dZ2, A1.T)/m
        db2 = np.sum(dZ2, axis=1, keepdims=True)/m
        dZ1 = np.multiply( np.dot( self.W2.T, dZ2), 1-np.power( A1, 2))
        dW1 = np.dot(dZ1, X.T)/m
        db1 = np.sum(dZ1, axis=1, keepdims=True)/m

        return dW1, db1, dW2, db2


    def fit(self, X, y , epochs, X_val, Y_val):
        """
        Learns parameters for the neural network and returns the model.

        @param: X: the training feature
        @param: y: the train label
        @param: epochs: Number of passes through the training data for gradient descent
        @param: X_val: the feature of validation set
        @param: y_val: the label of validation set
        """

        # Input checks: X and X_val needs to be in the form of n0 x m
        if (X.shape[0] > X.shape[1]): X = X.T
        if (X_val.shape[0] > X_val.shape[1]): X_val = X_val.T

        # Gradient descent
        for i in range(0, epochs):

            # SUBTASK 4: Compute the forward, backward, and gradient descent parameter update
            # Step 1: Forward pass
            A1, A2 = self.forward_pass(X)

            # Step 2: Backward pass
            dW1, db1, dW2, db2 = self.backward_pass(A1, A2, X, y)

            # Step 3: Gradient Descent
            self.W1 -= self.alpha * dW1
            self.b1 -= self.alpha * db1
            self.W2 -= self.alpha * dW2
            self.b2 -= self.alpha * db2

            # Print the loss and validation accuracy every 10 epochs.
            if i % 10 == 0:
                print("Epoch %i/%i - loss: %f - accuracy: %f - val_loss: %f - val_accuracy: %f"
                      %(i,epochs, self.loss(X, y), self.evaluate(X, y),
                        self.loss(X_val, y_val), self.evaluate(X_val,y_val)))

    def predict(self, X):
        """
        Predict label vector y
        """
        # check X for the form of n0 x m
        if (X.shape[0] > X.shape[1]): X = X.T

        # SUBTASK 5: Implement the prediction process.
        # Hint: It should include a forward pass, and then use the class with higher probability.
        A1, A2 = self.forward_pass(X)
        y_hat = np.argmax(A2, axis = 0)

        max_i = 0
        max_p = 0

        return y_hat


    def evaluate(self, X, y):
        """
        Evaluate the accuracy of the model
        """
        m = y.shape[0]
        y_hat = self.predict(X)
        correct_y = (y_hat == y).astype(int)

        return sum(correct_y)/m


    def one_hot(self, y):
        """
        Utility function: Convert a label vector to one-hot vector
        """
        Y = self.encoder.fit_transform(y.reshape(len(y),1))
        return Y.T # Transpose to get into same shape 1 x m


    def plot_decision_boundary(self, X, y):
        """
        Utility Function: Plot a decision boundary for visualization purpose.
        If you don't fully understand this function don't worry, it just generates the contour plot below.
        """
        # Set min and max values and give it some padding
        x_min, x_max = X[:,0].min() - .5, X[:,0].max() + .5
        y_min, y_max = X[:,1].min() - .5, X[:,1].max() + .5
        h = 0.01
        # Generate a grid of points with distance h between them
        xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
        # Predict the function value for the whole gid
        data_grid= np.c_[xx.ravel(), yy.ravel()]
        Z = self.predict(data_grid)
        Z = Z.reshape(xx.shape)

        # Plot the contour and training examples
        plt.contourf(xx, yy, Z, cmap=plt.cm.Pastel1)
        plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.Spectral)

# %% [markdown]
# ---
# ## 4. REFLECT ON THE COMPARISON BETWEEN YOUR IMPLEMENTATION TO THE STANDARD LIBRARY
# Now that you have implemented your own Neural Net class, let's use it! Create at least 3 instances of your Neural Net class, each with a different number of nodes in the hiden layer, tune it with the appropriate learning rate and number of iteration. You will test their performance in the Xor dataset and report the test accuracy metrics for each instance of your neural network.
#
# Based on the test accuracy, compare your models with the standard library version.

# %%
import warnings
warnings.filterwarnings("ignore")
# MODEL 1 here
n0 = len(X_train[0]) # input layer dimensionality
n1 = 500 # hidden layer dimensionality
n2 = 2 # output layer dimensionality
epochs = 100 # number of iteration/epochs

# Build a model with 3 layers
alpha_list = [0.01, 0.1, 1, 3]
for i in alpha_list:
  myModel1 = MyNeuralNet(n0, n1, n2, i);
  myModel1.fit(X_train, y_train, epochs, X_val, y_val)
  print("Accuracy on the test set is ", myModel1.evaluate(X_test, y_test))

  # Plot the decision boundary
myModel1 = MyNeuralNet(n0, n1, n2, 1);
myModel1.fit(X_train, y_train, epochs, X_val, y_val)
myModel1.plot_decision_boundary(X_train, y_train)
# Out:
# Epoch 0/100 - loss: 365.554947 - accuracy: 0.429167 - val_loss: 33.893818 - val_accuracy: 0.450000
n2 = 2 # output layer dimensionality
epochs = 100 # number of iteration/epochs

alpha_list = [0.01, 0.1, 1, 3]
for i in alpha_list:
  myModel1 = MyNeuralNet(n0, n1, n2, i);
  myModel1.fit(X_train, y_train, epochs, X_val, y_val)
  print("Accuracy on the test set is ", myModel1.evaluate(X_test, y_test))

# Plot the decision boundary
myModel1 = MyNeuralNet(n0, n1, n2, 1);
myModel1.fit(X_train, y_train, epochs, X_val, y_val)
myModel1.plot_decision_boundary(X_train, y_train)
# Out:
# Epoch 0/100 - loss: -413.273546 - accuracy: 0.513889 - val_loss: -56.318661 - val_accuracy: 0.412500
# Epoch 10/100 - loss: -267.970658 - accuracy: 0.516667 - val_loss: -31.537854 - val_accuracy: 0.462500
# Epoch 20/100 - loss: -263.323349 - accuracy: 0.518056 - val_loss: -30.822309 - val_accuracy: 0.475000
# Epoch 30/100 - loss: -259.085831 - accuracy: 0.519444 - val_loss: -30.191376 - val_accuracy: 0.487500
# Epoch 40/100 - loss: -255.192830 - accuracy: 0.526389 - val_loss: -29.621638 - val_accuracy: 0.487500
# Epoch 50/100 - loss: -251.589270 - accuracy: 0.527778 - val_loss: -29.103793 - val_accuracy: 0.487500
# Epoch 60/100 - loss: -248.228924 - accuracy: 0.527778 - val_loss: -28.629938 - val_accuracy: 0.487500
# Epoch 70/100 - loss: -245.073344 - accuracy: 0.529167 - val_loss: -28.193400 - val_accuracy: 0.487500
# Epoch 80/100 - loss: -242.090785 - accuracy: 0.534722 - val_loss: -27.788583 - val_accuracy: 0.487500
# Epoch 90/100 - loss: -239.255180 - accuracy: 0.534722 - val_loss: -27.410814 - val_accuracy: 0.487500
# Accuracy on the test set is  0.475
# Epoch 0/100 - loss: -1130.638225 - accuracy: 0.486111 - val_loss: -106.778037 - val_accuracy: 0.587500
# Epoch 10/100 - loss: -1046.662912 - accuracy: 0.490278 - val_loss: -100.684703 - val_accuracy: 0.587500
# Epoch 20/100 - loss: -991.995266 - accuracy: 0.515278 - val_loss: -96.423147 - val_accuracy: 0.587500
# Epoch 30/100 - loss: -941.353270 - accuracy: 0.543056 - val_loss: -92.014311 - val_accuracy: 0.600000
# Epoch 40/100 - loss: -899.510631 - accuracy: 0.555556 - val_loss: -88.245134 - val_accuracy: 0.612500
# Epoch 50/100 - loss: -862.930848 - accuracy: 0.561111 - val_loss: -84.908232 - val_accuracy: 0.625000
# Epoch 60/100 - loss: -827.893784 - accuracy: 0.569444 - val_loss: -81.688301 - val_accuracy: 0.625000
# Epoch 70/100 - loss: -792.106281 - accuracy: 0.573611 - val_loss: -78.379720 - val_accuracy: 0.637500
# Epoch 80/100 - loss: -754.191121 - accuracy: 0.583333 - val_loss: -74.856939 - val_accuracy: 0.637500
# Epoch 90/100 - loss: -713.205698 - accuracy: 0.590278 - val_loss: -71.033765 - val_accuracy: 0.650000
# Accuracy on the test set is  0.495
# Epoch 0/100 - loss: -15759.105783 - accuracy: 0.486111 - val_loss: -1467.316157 - val_accuracy: 0.587500
# Epoch 60/100 - loss: -21.018518 - accuracy: 0.988889 - val_loss: -3.552581 - val_accuracy: 0.962500
# Epoch 70/100 - loss: -19.069849 - accuracy: 0.988889 - val_loss: -3.363707 - val_accuracy: 0.962500
# Epoch 80/100 - loss: -17.602872 - accuracy: 0.988889 - val_loss: -3.220528 - val_accuracy: 0.962500
# Epoch 90/100 - loss: -16.459527 - accuracy: 0.988889 - val_loss: -3.108197 - val_accuracy: 0.962500

# %%
# MODEL 3 here
n0 = len(X_train[0]) # input layer dimensionality
n1 = 50 # hidden layer dimensionality
n2 = 2 # output layer dimensionality
epochs = 100 # number of iteration/epochs

# Build a model with 3 layers
alpha_list = [0.01, 0.1, 1, 3]
for i in alpha_list:
  myModel1 = MyNeuralNet(n0, n1, n2, i);
  myModel1.fit(X_train, y_train, epochs, X_val, y_val)
  print("Accuracy on the test set is ", myModel1.evaluate(X_test, y_test))

  # Plot the decision boundary
myModel1 = MyNeuralNet(n0, n1, n2, 1);
myModel1.fit(X_train, y_train, epochs, X_val, y_val)
myModel1.plot_decision_boundary(X_train, y_train)
# Out:
# Epoch 0/100 - loss: -258.090105 - accuracy: 0.652778 - val_loss: -27.504853 - val_accuracy: 0.662500
# Epoch 10/100 - loss: -255.744027 - accuracy: 0.562500 - val_loss: -27.654077 - val_accuracy: 0.550000
# Epoch 20/100 - loss: -254.088399 - accuracy: 0.526389 - val_loss: -27.611459 - val_accuracy: 0.537500
# Epoch 30/100 - loss: -252.550586 - accuracy: 0.511111 - val_loss: -27.509529 - val_accuracy: 0.537500
# Epoch 40/100 - loss: -251.086764 - accuracy: 0.508333 - val_loss: -27.394909 - val_accuracy: 0.537500
# Epoch 50/100 - loss: -249.689113 - accuracy: 0.511111 - val_loss: -27.280200 - val_accuracy: 0.537500
# Epoch 60/100 - loss: -248.352568 - accuracy: 0.512500 - val_loss: -27.168457 - val_accuracy: 0.537500
# Epoch 70/100 - loss: -247.072559 - accuracy: 0.513889 - val_loss: -27.060246 - val_accuracy: 0.550000
# Epoch 80/100 - loss: -245.844847 - accuracy: 0.527778 - val_loss: -26.955502 - val_accuracy: 0.575000
# Epoch 90/100 - loss: -244.665489 - accuracy: 0.551389 - val_loss: -26.854013 - val_accuracy: 0.587500
# Accuracy on the test set is  0.685
# Epoch 0/100 - loss: -255.906965 - accuracy: 0.466667 - val_loss: -27.938820 - val_accuracy: 0.500000
# Epoch 10/100 - loss: -242.452337 - accuracy: 0.747222 - val_loss: -26.663234 - val_accuracy: 0.787500
# Epoch 20/100 - loss: -233.190045 - accuracy: 0.729167 - val_loss: -25.819162 - val_accuracy: 0.775000
# Epoch 30/100 - loss: -225.740891 - accuracy: 0.723611 - val_loss: -25.094331 - val_accuracy: 0.775000
# Epoch 40/100 - loss: -219.045496 - accuracy: 0.737500 - val_loss: -24.414669 - val_accuracy: 0.775000
# Epoch 50/100 - loss: -212.618060 - accuracy: 0.756944 - val_loss: -23.745989 - val_accuracy: 0.787500
# Epoch 10/100 - loss: -357.215368 - accuracy: 0.513889 - val_loss: -46.594913 - val_accuracy: 0.412500
# Epoch 20/100 - loss: -218.324242 - accuracy: 0.513889 - val_loss: -28.061562 - val_accuracy: 0.412500
# Epoch 30/100 - loss: -157.784760 - accuracy: 0.702778 - val_loss: -20.602638 - val_accuracy: 0.687500
# Epoch 40/100 - loss: -67.950737 - accuracy: 0.976389 - val_loss: -8.947743 - val_accuracy: 0.950000
# Epoch 50/100 - loss: -41.797819 - accuracy: 0.986111 - val_loss: -5.632125 - val_accuracy: 0.962500
# Epoch 60/100 - loss: -32.810759 - accuracy: 0.986111 - val_loss: -4.678978 - val_accuracy: 0.975000
# Epoch 70/100 - loss: -27.389466 - accuracy: 0.986111 - val_loss: -4.102088 - val_accuracy: 0.975000
# Epoch 80/100 - loss: -23.821210 - accuracy: 0.986111 - val_loss: -3.719800 - val_accuracy: 0.975000
# Epoch 90/100 - loss: -21.317732 - accuracy: 0.987500 - val_loss: -3.450337 - val_accuracy: 0.975000

# %%
# COMPARISONS WITH THE STANDARD LIBRARY
import tensorflow as tf
from tensorflow import keras

my_model = keras.Sequential()
# Your code here!
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[2, ]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(2, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy" ,
              optimizer="sgd",
              metrics=["accuracy"])

xor_library = model.fit(X_train, y_train, batch_size=64, epochs=100,
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 38ms/step - loss: 0.6854 - accuracy: 0.3792 - val_loss: 0.6820 - val_accuracy: 0.4625
# Epoch 2/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6807 - accuracy: 0.5486 - val_loss: 0.6779 - val_accuracy: 0.5125
# Epoch 3/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6761 - accuracy: 0.6250 - val_loss: 0.6733 - val_accuracy: 0.5375
# Epoch 4/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6717 - accuracy: 0.6333 - val_loss: 0.6699 - val_accuracy: 0.5875
# Epoch 5/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6673 - accuracy: 0.6792 - val_loss: 0.6655 - val_accuracy: 0.5875
# Epoch 6/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6629 - accuracy: 0.6861 - val_loss: 0.6617 - val_accuracy: 0.6125
# Epoch 7/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6588 - accuracy: 0.7056 - val_loss: 0.6582 - val_accuracy: 0.6125
# Epoch 8/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6547 - accuracy: 0.7167 - val_loss: 0.6537 - val_accuracy: 0.7125
# Epoch 9/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6507 - accuracy: 0.7944 - val_loss: 0.6497 - val_accuracy: 0.7500
# Epoch 10/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6469 - accuracy: 0.8278 - val_loss: 0.6460 - val_accuracy: 0.7875
# Epoch 11/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6431 - accuracy: 0.8486 - val_loss: 0.6424 - val_accuracy: 0.8000
# Epoch 12/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6394 - accuracy: 0.8792 - val_loss: 0.6395 - val_accuracy: 0.7875
# Epoch 13/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6357 - accuracy: 0.8639 - val_loss: 0.6351 - val_accuracy: 0.8375
# Epoch 14/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6320 - accuracy: 0.8986 - val_loss: 0.6313 - val_accuracy: 0.8500
# Epoch 15/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6284 - accuracy: 0.8958 - val_loss: 0.6269 - val_accuracy: 0.8750
# Epoch 16/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6249 - accuracy: 0.9139 - val_loss: 0.6237 - val_accuracy: 0.8750
# Epoch 17/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6214 - accuracy: 0.9222 - val_loss: 0.6200 - val_accuracy: 0.8750
# Epoch 18/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6180 - accuracy: 0.9250 - val_loss: 0.6172 - val_accuracy: 0.8750
# Epoch 19/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6146 - accuracy: 0.9292 - val_loss: 0.6122 - val_accuracy: 0.8875
# Epoch 20/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6112 - accuracy: 0.9361 - val_loss: 0.6092 - val_accuracy: 0.9000
# Epoch 21/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6079 - accuracy: 0.9375 - val_loss: 0.6064 - val_accuracy: 0.9000
# Epoch 22/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6046 - accuracy: 0.9375 - val_loss: 0.6032 - val_accuracy: 0.9000
# Epoch 23/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6012 - accuracy: 0.9417 - val_loss: 0.6004 - val_accuracy: 0.8875
# Epoch 24/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5979 - accuracy: 0.9375 - val_loss: 0.5966 - val_accuracy: 0.9000
# Epoch 25/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5947 - accuracy: 0.9431 - val_loss: 0.5929 - val_accuracy: 0.9000
# Epoch 26/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5915 - accuracy: 0.9458 - val_loss: 0.5897 - val_accuracy: 0.9125
# Epoch 27/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5881 - accuracy: 0.9500 - val_loss: 0.5867 - val_accuracy: 0.9125
# Epoch 28/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5849 - accuracy: 0.9486 - val_loss: 0.5827 - val_accuracy: 0.9375
# Epoch 29/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5817 - accuracy: 0.9514 - val_loss: 0.5796 - val_accuracy: 0.9375
# Epoch 30/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5783 - accuracy: 0.9528 - val_loss: 0.5763 - val_accuracy: 0.9375
# Epoch 31/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5751 - accuracy: 0.9514 - val_loss: 0.5726 - val_accuracy: 0.9375
# Epoch 32/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5719 - accuracy: 0.9514 - val_loss: 0.5691 - val_accuracy: 0.9375
# Epoch 33/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5687 - accuracy: 0.9542 - val_loss: 0.5661 - val_accuracy: 0.9500
# Epoch 34/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5655 - accuracy: 0.9569 - val_loss: 0.5629 - val_accuracy: 0.9500
# Epoch 35/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5622 - accuracy: 0.9542 - val_loss: 0.5591 - val_accuracy: 0.9500
# Epoch 36/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5590 - accuracy: 0.9569 - val_loss: 0.5558 - val_accuracy: 0.9500
# Epoch 37/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5558 - accuracy: 0.9556 - val_loss: 0.5528 - val_accuracy: 0.9500
# Epoch 38/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5526 - accuracy: 0.9597 - val_loss: 0.5490 - val_accuracy: 0.9500
# Epoch 39/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5495 - accuracy: 0.9528 - val_loss: 0.5456 - val_accuracy: 0.9500
# Epoch 40/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5462 - accuracy: 0.9583 - val_loss: 0.5429 - val_accuracy: 0.9500
# Epoch 41/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5429 - accuracy: 0.9583 - val_loss: 0.5403 - val_accuracy: 0.9500
# Epoch 42/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5397 - accuracy: 0.9597 - val_loss: 0.5373 - val_accuracy: 0.9500
# Epoch 43/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5366 - accuracy: 0.9611 - val_loss: 0.5341 - val_accuracy: 0.9500
# Epoch 44/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5333 - accuracy: 0.9597 - val_loss: 0.5308 - val_accuracy: 0.9500
# Epoch 45/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5301 - accuracy: 0.9597 - val_loss: 0.5278 - val_accuracy: 0.9500
# Epoch 46/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5268 - accuracy: 0.9597 - val_loss: 0.5247 - val_accuracy: 0.9500
# Epoch 47/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.
100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4304 - accuracy: 0.9722 - val_loss: 0.4275 - val_accuracy: 0.9375
# Epoch 77/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4272 - accuracy: 0.9722 - val_loss: 0.4241 - val_accuracy: 0.9500
# Epoch 78/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4241 - accuracy: 0.9722 - val_loss: 0.4208 - val_accuracy: 0.9500
# Epoch 79/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4210 - accuracy: 0.9722 - val_loss: 0.4181 - val_accuracy: 0.9500
# Epoch 80/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4180 - accuracy: 0.9736 - val_loss: 0.4160 - val_accuracy: 0.9375
# Epoch 81/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4149 - accuracy: 0.9694 - val_loss: 0.4121 - val_accuracy: 0.9375
# Epoch 82/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4117 - accuracy: 0.9722 - val_loss: 0.4088 - val_accuracy: 0.9500
# Epoch 83/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4087 - accuracy: 0.9722 - val_loss: 0.4061 - val_accuracy: 0.9500
# Epoch 84/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4055 - accuracy: 0.9722 - val_loss: 0.4022 - val_accuracy: 0.9500
# Epoch 85/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4024 - accuracy: 0.9736 - val_loss: 0.3992 - val_accuracy: 0.9500
# Epoch 86/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3994 - accuracy: 0.9722 - val_loss: 0.3963 - val_accuracy: 0.9500
# Epoch 87/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3964 - accuracy: 0.9722 - val_loss: 0.3935 - val_accuracy: 0.9500
# Epoch 88/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3934 - accuracy: 0.9722 - val_loss: 0.3907 - val_accuracy: 0.9500
# Epoch 89/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3904 - accuracy: 0.9736 - val_loss: 0.3879 - val_accuracy: 0.9500
# Epoch 90/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3874 - accuracy: 0.9722 - val_loss: 0.3850 - val_accuracy: 0.9500
# Epoch 91/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3844 - accuracy: 0.9722 - val_loss: 0.3820 - val_accuracy: 0.9500
# Epoch 92/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3815 - accuracy: 0.9722 - val_loss: 0.3791 - val_accuracy: 0.9500
# Epoch 93/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3786 - accuracy: 0.9722 - val_loss: 0.3760 - val_accuracy: 0.9500
# Epoch 94/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3756 - accuracy: 0.9736 - val_loss: 0.3732 - val_accuracy: 0.9500
# Epoch 95/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3728 - accuracy: 0.9708 - val_loss: 0.3705 - val_accuracy: 0.9500
# Epoch 96/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3699 - accuracy: 0.9722 - val_loss: 0.3680 - val_accuracy: 0.9500
# Epoch 97/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3671 - accuracy: 0.9708 - val_loss: 0.3650 - val_accuracy: 0.9500
# Epoch 98/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3642 - accuracy: 0.9708 - val_loss: 0.3622 - val_accuracy: 0.9500
# Epoch 99/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3614 - accuracy: 0.9708 - val_loss: 0.3591 - val_accuracy: 0.9500
# Epoch 100/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3586 - accuracy: 0.9708 - val_loss: 0.3560 - val_accuracy: 0.9500

# %%
xor_library.history['accuracy']
# Out:
# [0.3791666626930237,
#  0.5486111044883728,
#  0.625,
#  0.6333333253860474,
#  0.6791666746139526,
#  0.6861110925674438,
#  0.7055555582046509,
#  0.7166666388511658,
#  0.7944444417953491,
#  0.8277778029441833,
#  0.8486111164093018,
#  0.8791666626930237,
#  0.8638888597488403,
#  0.8986111283302307,
#  0.8958333134651184,
#  0.9138888716697693,
#  0.9222221970558167,
#  0.925000011920929,
#  0.9291666746139526,
#  0.9361110925674438,
#  0.9375,
#  0.9375,
#  0.9416666626930237,
#  0.9375,
#  0.9430555701255798,
#  0.9458333253860474,
#  0.949999988079071,
#  0.9486111402511597,
#  0.9513888955116272,
#  0.9527778029441833,
#  0.9513888955116272,
#  0.9513888955116272,
#  0.9541666507720947,
#  0.956944465637207,
#  0.9541666507720947,
#  0.956944465637207,
#  0.9555555582046509,
#  0.9597222208976746,
#  0.9527778029441833,
#  0.9583333134651184,
#  0.9583333134651184,
#  0.9597222208976746,
#  0.9611111283302307,
#  0.9597222208976746,
#  0.9597222208976746,
#  0.9597222208976746,
#  0.9611111283302307,
#  0.9597222208976746,
#  0.9611111283302307,
#  0.9611111283302307,
#  0.9611111283302307,
#  0.9624999761581421,
#  0.9652777910232544,
#  0.9638888835906982,
#  0.9638888835906982,
#  0.9638888835906982,
#  0.9666666388511658,
#  0.9666666388511658,
#  0.9680555462837219,
#  0.9680555462837219,
#  0.9694444537162781,
#  0.9708333611488342,
#  0.9694444537162781,
#  0.9680555462837219,
#  0.9680555462837219,
#  0.9680555462837219,
#  0.9694444537162781,
#  0.9708333611488342,
#  0.9722222089767456,
#  0.9736111164093018,
#  0.9722222089767456,
#  0.9708333611488342,
#  0.9722222089767456,
#  0.9708333611488342,
#  0.9736111164093018,
#  0.9722222089767456,
#  0.9722222089767456,
#  0.9722222089767456,
#  0.9722222089767456,
#  0.9736111164093018,
#  0.9694444537162781,
#  0.9722222089767456,
#  0.9722222089767456,
#  0.9722222089767456,
#  0.9736111164093018,
#  0.9722222089767456,
#  0.9722222089767456,
#  0.9722222089767456,
#  0.9736111164093018,
#  0.9722222089767456,
#  0.9722222089767456,
#  0.9722222089767456,
#  0.9722222089767456,
#  0.9736111164093018,
#  0.9708333611488342,
#  0.9722222089767456,
#  0.9708333611488342,
#  0.9708333611488342,
#  0.9708333611488342,
#  0.9708333611488342]

# %% [markdown]
# ## Reflection
# Write at least a paragraph answering these prompts: How did your own network perform? Is there any major differences between the implementations? Finally, reflecting on your experience implementing a learning algorithm for this assignment (Was it hard/easy/fun?, From which part did you learn the most?)!

# %% [markdown]
# My implementation of the network performs reasonably well but with certain limitations. My model can only construct 1 hidden layer, and it cannot select the batch size for each epoch. As a result, my model surprisingly performs slightly better than the standard library. This learning algorithm assignment is not that hard compared to the kernel one, and now I have a deeper, more detailed understanding of the back propagation and the parameter update using derivates.

# %% [markdown]
# ---
# # Get Help?
# In case you get stuck in any step in the process, you may find some useful information from:
#
#  * Consult my [lecture 13](https://docs.google.com/presentation/d/1otQfmMomWctLZKI3hHKAA4lLkbXFtagLaQov8gNh4LI/edit?usp=sharing) and [Colab Notebook 10](https://colab.research.google.com/drive/1x5biI3dP5YvvDEI0wapJcSgQNnATDzNe)
#  * Talk to the TA, they are available and there to help you during office hour.
#  * Come talk to me or email me <nn4pj@virginia.edu> with subject starting "CS4774 Assignment 4:...".
#
# Part of the codes used in this assignment is modified from Konstantinos Kitsios under the 3-Clause BSD License. Best of luck and have fun!
